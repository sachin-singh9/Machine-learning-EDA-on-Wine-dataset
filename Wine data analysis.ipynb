# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import statsmodels.api as stm

# %%
os.chdir(r"C:\Users\vset Info\Downloads")

# %%
df=pd.read_csv("winequalityN.csv")
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.quality.unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
df.columns
# Out:
# Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.220172     0.323736
# volatile acidity           0.220172          1.000000    -0.378061
# citric acid                0.323736         -0.378061     1.000000
# residual sugar            -0.112319         -0.196702     0.142486
# chlorides                  0.298421          0.377167     0.039315
# free sulfur dioxide       -0.283317         -0.353230     0.133437
# total sulfur dioxide      -0.329747         -0.414928     0.195218
# density                    0.459204          0.271193     0.096320
# pH                        -0.251814          0.260660    -0.328689
# sulphates                  0.300380          0.225476     0.057613
# alcohol                   -0.095603         -0.038248    -0.010433
# quality                   -0.077031         -0.265953     0.085706
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
df.hist(bins=25,figsize=(10,10))

plt.show()

# %%
plt.figure(figsize=[10,6])
# plot bar graph
plt.bar(df['quality'],df['alcohol'],color='orange')
# label x-axis
plt.xlabel('quality')
#label y-axis
plt.ylabel('alcohol')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
df.update(df.fillna(df.mean()))
# Out:
# C:\Users\VSETIN~1\AppData\Local\Temp/ipykernel_20272/217285154.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.update(df.fillna(df.mean()))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.type
# Out:
# 0       white
# 1       white
# 2       white
# 3       white
# 4       white
#         ...
# 6492      red
# 6493      red
# 6494      red
# 6495      red
# 6496      red
# Name: type, Length: 6497, dtype: object

# %%
next_df = pd.get_dummies(df,drop_first=True)
# display new dataframe
next_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.columns.values
# Out:
# array(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %% [markdown]
# # REGRESSION TREE

# %%
df1=pd.read_csv("winequalityN.csv")

# %%
df1
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df1.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.220172     0.323736
# volatile acidity           0.220172          1.000000    -0.378061
# citric acid                0.323736         -0.378061     1.000000
# residual sugar            -0.112319         -0.196702     0.142486
# chlorides                  0.298421          0.377167     0.039315
# free sulfur dioxide       -0.283317         -0.353230     0.133437
# total sulfur dioxide      -0.329747         -0.414928     0.195218
# density                    0.459204          0.271193     0.096320
# pH                        -0.251814          0.260660    -0.328689
# sulphates                  0.300380          0.225476     0.057613
# alcohol                   -0.095603         -0.038248    -0.010433
# quality                   -0.077031         -0.265953     0.085706
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
new_df=df1.drop('total sulfur dioxide',axis=1)

# %%
new_df.isnull().sum()
# Out:
# type                    0
# fixed acidity          10
# volatile acidity        8
# citric acid             3
# residual sugar          2
# chlorides               2
# free sulfur dioxide     0
# density                 0
# pH                      9
# sulphates               4
# alcohol                 0
# quality                 0
# dtype: int64

# %%
new_df.update(new_df.fillna(new_df.median()))
# Out:
# C:\Users\VSETIN~1\AppData\Local\Temp/ipykernel_20272/2452053682.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_df.update(new_df.fillna(new_df.median()))

# %%
next_df = pd.get_dummies(new_df,drop_first=True)
next_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
x=next_df.drop(["quality"],axis=1)
y=next_df.quality

# %% [markdown]
# # Train-Validation-Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train,x_valid,y_train,y_valid=train_test_split(x_train,y_train,test_size=0.25)

# %% [markdown]
# # Fitting a Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
reg_tree=DecisionTreeRegressor(max_depth=2,min_samples_leaf=100,min_samples_split= 2)#greedy algorithm
reg_tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=2, min_samples_leaf=100)

# %% [markdown]
# # Plotting a Regression Tree

# %%
from sklearn import tree
fig,axes=plt.subplots(figsize=(5,5),dpi=300)
tree.plot_tree(reg_tree,feature_names=list(x),filled=False)
plt.show()

# %% [markdown]
# # Prediction

# %%
y_pred=reg_tree.predict(x_valid)
y_pred
# Out:
# array([5.81635926, 6.47147846, 6.47147846, ..., 6.05720339, 5.81635926,
#        5.81635926])

# %% [markdown]
# # Model Performance Checks

# %%
#MAE
np.mean(np.abs(y_valid-y_pred))
# Out:
# 0.6293933430968455

# %%
#MSE
np.mean((y_valid- y_pred)**2)
# Out:
# 0.6435826789499103

# %%
#RMSE
np.sqrt(np.mean((y_valid-y_pred)**2))
# Out:
# 0.8022360493956316

# %%
#MAPE
np.mean(np.abs(y_valid-y_pred)/y_valid)*100
# Out:
# 11.230362750846833

# %% [markdown]
# # Hyperparameter Tuning -Choosing Best Depth

# %%
depth=np.arange(1,20)
mae=[]
for k in depth:
    reg_tree=DecisionTreeRegressor(max_depth=k,min_samples_leaf=5)
    reg_tree.fit(x_train,y_train)
    y_pred=reg_tree.predict(x_valid)
    mae.append(np.mean(np.abs(y_valid-y_pred))) #MAD

# %%
plt.plot(depth,np.array(mae))
plt.show()

# %% [markdown]
# # Testing with Different hyperparameters

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
'max_depth': [4,5,6,7,8,9,10,11,None],
'min_samples_split' : [100,200,300,400,500],
'min_samples_leaf' : [50,100,250,400]}




grid = GridSearchCV( DecisionTreeRegressor(), params, cv=2, n_jobs=-1)
grid.fit(x_valid, y_valid)

grid.best_score_
# Out:
# 0.22579207890543357

# %%
grid.best_params_
# Out:
# {'max_depth': 4, 'min_samples_leaf': 100, 'min_samples_split': 300}

# %% [markdown]
# # Final Testing

# %%
#Fit aDT model of depth 5 on the training data and test its performance on 
#the test data by calculating the MAE
reg_tree=DecisionTreeRegressor(max_depth= 4, min_samples_leaf= 100, min_samples_split= 300)#greedy algorithm
reg_tree.fit(x_train,y_train)
y_pred=reg_tree.predict(x_test)

np.mean(np.abs(y_test-y_pred))
# Out:
# 0.5780230280860038

# %%
#MSE
np.mean((y_test- y_pred)**2)
# Out:
# 0.5360606465638212

# %%
#RMSE
np.sqrt(np.mean((y_test-y_pred)**2))
# Out:
# 0.7321616259841957

# %%
#MAPE
np.mean(np.abs(y_test-y_pred)/y_test)*100
# Out:
# 10.344651052305796

# %% [markdown]
# # LINEAR REGRESSION

# %%
y=df.quality
x=df[['fixed acidity', 'volatile acidity', 'citric acid',
       'residual sugar', 'chlorides', 'free sulfur dioxide',
        'density', 'pH', 'sulphates', 'alcohol']]
x=stm.add_constant(x)
x
# Out:
# E:\anaconda\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#       const  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0       1.0            7.0             0.270         0.36            20.7
# 1       1.0            6.3             0.300         0.34             1.6
# 2       1.0            8.1             0.280         0.40             6.9
# 3       1.0            7.2             0.230         0.32             8.5
# 4       1.0            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    1.0            6.2             0.600         0.08             2.0
# 6493    1.0            5.9             0.550         0.10             2.2
# 6494    1.0            6.3             0.510         0.13             2.3
# ...

# %%
model=stm.OLS(y,x).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.283
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     256.4
# Date:                Thu, 03 Nov 2022   Prob (F-statistic):               0.00
# Time:                        18:25:38   Log-Likelihood:                -7255.7
# No. Observations:                6497   AIC:                         1.453e+04
# Df Residuals:                    6486   BIC:                         1.461e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
model.predict(x)
# Out:
# 0       5.513461
# 1       5.368166
# 2       5.799656
# 3       5.770589
# 4       5.770589
#           ...
# 6492    5.473837
# 6493    5.740794
# 6494    5.833791
# 6495    5.422128
# 6496    5.949726
# Length: 6497, dtype: float64

# %%
np.sum((y-model.predict(x))**2)
# Out:
# 3550.226359708093

# %%
#MAE
np.mean(np.abs(y-model.predict(x)))
# Out:
# 0.57290643684251

# %%
#MSE
np.mean((y-model.predict(x))**2)
# Out:
# 0.5464408742047234

# %%
#RMSE
np.sqrt(np.mean((y-model.predict(x))**2))
# Out:
# 0.7392163920021819

# %%
#MAPE
np.mean(np.abs(y_valid-y_pred)/y_valid)*100
# Out:
# 10.260720162254316
